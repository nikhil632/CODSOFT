# %%
import pandas as pd 
import numpy as np
import pickle

# %%
df = pd.read_csv('fraudTrain-Copy1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
df= df[['category','gender','amt','city','state','lat','long','job','is_fraud']]

# %%
from sklearn.utils import resample #balancing both values
df_majority=df[df.is_fraud==0]
df_minority=df[df.is_fraud==1]
print(df_majority.shape,df_minority.shape)
# Out:
# (1289169, 9) (7506, 9)

# %%
df_minority_unsampled=resample(df_minority,n_samples=100000,random_state=123)
mydata3=pd.concat([df_majority[:100000],df_minority_unsampled])
print(df_minority_unsampled.shape,mydata3.shape)
# Out:
# (100000, 9) (200000, 9)

# %%
mydata3['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    100000
# 1    100000
# Name: count, dtype: int64

# %%
mydata3
# Out:
#               category gender     amt            city state      lat  \
# 0             misc_net      F    4.97  Moravian Falls    NC  36.0788
# 1          grocery_pos      F  107.23          Orient    WA  48.8878
# 2        entertainment      M  220.11      Malad City    ID  42.1808
# 3        gas_transport      M   45.00         Boulder    MT  46.2306
# 4             misc_pos      M   41.96        Doe Hill    VA  38.4207
# ...                ...    ...     ...             ...   ...      ...
# 869252    shopping_net      M  974.87        Columbia    SC  33.9659
# 83957      grocery_pos      M  284.63          Warren    MI  42.5164
# 1023381       misc_net      F  672.71     Los Angeles    CA  34.0443
# 598604    shopping_net      F  941.63         Brandon    FL  27.9551
# 1071190    grocery_pos      F  298.64           Tulsa    OK  36.1499
#
#              long                                job  is_fraud
# 0        -81.1781          Psychologist, counselling         0
# ...

# %%
mydata3["gender"].unique() #checking unique values
# Out:
# array(['F', 'M'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1=LabelEncoder()
cut_lbl=le1.fit(mydata3["category"])
mydata3["category_label"]= le1.transform(mydata3["category"])

le2=LabelEncoder()
cut_lbl=le2.fit(mydata3["gender"])
mydata3["gender_label"]= le2.transform(mydata3["gender"])

le3=LabelEncoder()
cut_lebl=le3.fit(mydata3["city"])
mydata3["city_label"]=le3.transform(mydata3["city"])

le4=LabelEncoder()
cut_lebl=le4.fit(mydata3["state"])
mydata3["state_label"]=le4.transform(mydata3["state"])

le5=LabelEncoder()
cut_lebl=le5.fit(mydata3["job"])
mydata3["job_label"]=le5.transform(mydata3["job"])

# %%
le3.inverse_transform([339]) #city unique value
# Out:
# array(['Heidelberg'], dtype=object)

# %%
le4.inverse_transform([39]) #unique state
# Out:
# array(['RI'], dtype=object)

# %%
le5.inverse_transform([89])
# Out:
# array(['Clinical psychologist'], dtype=object)

# %%
mydata3
# Out:
#               category gender     amt            city state      lat  \
# 0             misc_net      F    4.97  Moravian Falls    NC  36.0788
# 1          grocery_pos      F  107.23          Orient    WA  48.8878
# 2        entertainment      M  220.11      Malad City    ID  42.1808
# 3        gas_transport      M   45.00         Boulder    MT  46.2306
# 4             misc_pos      M   41.96        Doe Hill    VA  38.4207
# ...                ...    ...     ...             ...   ...      ...
# 869252    shopping_net      M  974.87        Columbia    SC  33.9659
# 83957      grocery_pos      M  284.63          Warren    MI  42.5164
# 1023381       misc_net      F  672.71     Los Angeles    CA  34.0443
# 598604    shopping_net      F  941.63         Brandon    FL  27.9551
# 1071190    grocery_pos      F  298.64           Tulsa    OK  36.1499
#
#              long                                job  is_fraud  \
# 0        -81.1781          Psychologist, counselling         0
# ...

# %%
dff =mydata3.drop(['category','gender','city','state','job'],axis=1)

# %%
dff
# Out:
#             amt      lat      long  is_fraud  category_label  gender_label  \
# 0          4.97  36.0788  -81.1781         0               8             0
# 1        107.23  48.8878 -118.2105         0               4             0
# 2        220.11  42.1808 -112.2620         0               0             1
# 3         45.00  46.2306 -112.1138         0               2             1
# 4         41.96  38.4207  -79.4629         0               9             1
# ...         ...      ...       ...       ...             ...           ...
# 869252   974.87  33.9659  -80.9355         1              11             1
# 83957    284.63  42.5164  -82.9832         1               4             1
# 1023381  672.71  34.0443 -118.2509         1               8             0
# 598604   941.63  27.9551  -82.2966         1              11             0
# 1071190  298.64  36.1499  -95.7923         1               4             0
#
#          city_label  state_label  job_label
# ...

# %%
cat_list=list(dff["category_label"].unique())
cat_list
# Out:
# [np.int64(8),
#  np.int64(4),
#  np.int64(0),
#  np.int64(2),
#  np.int64(9),
#  np.int64(3),
#  np.int64(11),
#  np.int64(12),
#  np.int64(1),
#  np.int64(10),
#  np.int64(5),
#  np.int64(13),
#  np.int64(7),
#  np.int64(6)]

# %%
print(le1.inverse_transform(cat_list))
# Out:
# ['misc_net' 'grocery_pos' 'entertainment' 'gas_transport' 'misc_pos'
#  'grocery_net' 'shopping_net' 'shopping_pos' 'food_dining' 'personal_care'
#  'health_fitness' 'travel' 'kids_pets' 'home']

# %%
cat_list
# Out:
# [np.int64(8),
#  np.int64(4),
#  np.int64(0),
#  np.int64(2),
#  np.int64(9),
#  np.int64(3),
#  np.int64(11),
#  np.int64(12),
#  np.int64(1),
#  np.int64(10),
#  np.int64(5),
#  np.int64(13),
#  np.int64(7),
#  np.int64(6)]

# %%
x=dff.drop("is_fraud",axis=1)#independent variable
y=dff["is_fraud"] #Dependant variable

# %%
from sklearn import preprocessing
#x=preprocessing.normalize(x)
#y=preprocessing scale(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
rfc= RandomForestClassifier(n_estimators=100)
lr = LogisticRegression(max_iter=1000)
dtc=DecisionTreeClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn import metrics

# %%
print("Accuracy of model:",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy of model: 0.9966

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred1=rfc.predict(x_test)

# %%
print("Accuracy of model:",metrics.accuracy_score(y_test,y_pred1))
# Out:
# Accuracy of model: 0.9966

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=rfc.predict(x_test)

# %%
print("Accuracy of model:",metrics.accuracy_score(y_test,y_pred2))
# Out:
# Accuracy of model: 0.9966

# %%
filename='random_forest.sav'
pickle.dump(rfc,open(filename,'wb'))

# %%
filename='random_forest.sav'
loaded_model_nb=pickle.load(open(filename,'rb'))
